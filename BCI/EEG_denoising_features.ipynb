# %%
import numpy as np
import mne
from utils.loader import unicorn_fs
from utils.feature_extraction import extract_features
from utils.load_dataset import load_dataset, generate_samples
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import plot_model
from matplotlib import pyplot

mne.set_log_level(verbose='ERROR', return_old_level=False, add_frames=None)

# %matplotlib inline
#matplotlib.use("Qt5Agg")

# %% [markdown]
# ### Preprocessing
#
# 1. Read Data
# 2. Generate Samples
# 3. Extract Features

# %%
# Read dataset and generate samples

# Playing solo
path_dataset_1 = 'data/dataset/playing_solo'
labels_2 = ['baseline', 'playing']

dataset_1 = load_dataset(path_dataset_1, labels_2)
eeg_baseline_1 = dataset_1['baseline']
eeg_playing = dataset_1['playing']

# Playing and listening
path_dataset_2 = 'data/dataset/playing_listening'
labels_2 = ['baseline', 'relax', 'excited']

dataset_2 = load_dataset(path_dataset_2, labels_2)
eeg_baseline_2 = dataset_2['baseline']
eeg_playing_relax = dataset_2['relax']
eeg_playing_excited = dataset_2['excited']

# Listening
path_dataset_3 = 'data/dataset/listening'
labels_3 = ['baseline', 'relax', 'excited']

dataset_3 = load_dataset(path_dataset_3, labels_3)
eeg_baseline_3 = dataset_3['baseline']
eeg_listening_relax = dataset_3['relax']
eeg_listening_excited = dataset_3['excited']

# -----------------------------------------

window_duration = 4 # seconds
window_size = window_duration * unicorn_fs # samples
window_overlap = 0.875 # percentage

print('\nBaseline 1')
eeg_baseline_samples = generate_samples(eeg_baseline_1, window_size, window_overlap)
print('\nPlaying Solo')
eeg_playing_samples = generate_samples(eeg_playing, window_size, window_overlap)
print('\nBaseline 2')
eeg_baseline_samples_2 = generate_samples(eeg_baseline_2, window_size, window_overlap)
print('\nPlaying Relax')
eeg_playing_relax_samples = generate_samples(eeg_playing_relax, window_size, window_overlap)
print('\nPlaying Excited')
eeg_playing_excited_samples = generate_samples(eeg_playing_excited, window_size, window_overlap)
print('\nBaseline 3')
eeg_baseline_samples_3 = generate_samples(eeg_baseline_3, window_size, window_overlap)
print('\nListening Relax')
eeg_listening_relax_samples = generate_samples(eeg_listening_relax, window_size, window_overlap)
print('\nListening Excited')
eeg_listening_excited_samples = generate_samples(eeg_listening_excited, window_size, window_overlap)
# Out:
# Loading file: data/dataset/playing_solo\baseline\baseline_playing_solo.csv
# Loading file: data/dataset/playing_solo\playing\song_playing_solo.csv
# Loading file: data/dataset/playing_listening\baseline\baseline_playing_listening_excited.csv
# Loading file: data/dataset/playing_listening\relax\song_playing_listening_relax.csv
# Loading file: data/dataset/playing_listening\excited\song_playing_listening_excited.csv
# Loading file: data/dataset/listening\baseline\baseline_listening_excited.csv
# Loading file: data/dataset/listening\relax\song_listening_relax.csv
# Loading file: data/dataset/listening\excited\song_listening_excited.csv
#
# Baseline 1
# Sample dimension: (1000, 8)
# Number of samples: 162
#
# Playing Solo
# Sample dimension: (1000, 8)
# Number of samples: 452
#
# Baseline 2
# Sample dimension: (1000, 8)
# Number of samples: 162
#
# Playing Relax
# Sample dimension: (1000, 8)
# Number of samples: 452
#
# Playing Excited
# Sample dimension: (1000, 8)
# Number of samples: 452
#
# Baseline 3
# Sample dimension: (1000, 8)
# Number of samples: 162
#
# Listening Relax
# Sample dimension: (1000, 8)
# Number of samples: 462
#
# Listening Excited
# Sample dimension: (1000, 8)
# Number of samples: 452

# %%
# Extract features
features_playing_solo, baseline_1 = extract_features(eeg_baseline_samples, eeg_playing_samples)
features_playing_listening_relax, baseline_2 = extract_features(eeg_baseline_samples_2, eeg_playing_relax_samples)
features_playing_listening_excited, _ = extract_features(eeg_baseline_samples_2, eeg_playing_excited_samples, baseline_2)
features_listening_relax, baseline_3 = extract_features(eeg_baseline_samples_3, eeg_listening_relax_samples)
features_listening_excited, _ = extract_features(eeg_baseline_samples_3, eeg_listening_excited_samples, baseline_3)

# print
print('\nPlaying Solo:', features_playing_solo.shape)
print('Playing and Listening Relax:', features_playing_listening_relax.shape)
print('Playing and Listening Excited:', features_playing_listening_excited.shape)
print('Listening Relax:', features_listening_relax.shape)
print('Listening Excited:', features_listening_excited.shape)
# Out:
# Extracting bands from sample: 162/162
# Extracting bands from sample: 452/452
# Extracting bands from sample: 162/162
# Extracting bands from sample: 452/452
# Extracting bands from sample: 452/452
# Extracting bands from sample: 162/162
# Extracting bands from sample: 462/462
# Extracting bands from sample: 452/452
# Playing Solo
# (452, 40)
# Playing and Listening Relax
# (452, 40)
# Playing and Listening Excited
# (452, 40)
# Listening Relax
# (462, 40)
# Listening Excited
# (452, 40)

# %% [markdown]
# #### Denoising Autoencoder
#
# ![keras_denoising_autoencoder.png](attachment:keras_denoising_autoencoder.png)
#
#
# 1. Prepare data
# 2. Define the architecture
# 3. Train the model
# 4. Plot Results

# %% [markdown]
# ##### 1. Prepare Data

# %%
# define dataset
n = 450

# X = np.vstack((features_playing_solo[:n], 
#                features_playing_listening_relax[:n], 
#                features_playing_listening_excited[:n]))

# playing_solo_truth = []
# for i in range(n):
#     playing_solo_truth.append(baseline_1)
# playing_solo_truth = np.array(playing_solo_truth)

# y = np.vstack((playing_solo_truth,
#                features_listening_relax[:n],
#                features_listening_excited[:n]))


X = np.vstack((features_playing_listening_relax[:n], 
               features_playing_listening_excited[:n]))

y = np.vstack((features_listening_relax[:n],
               features_listening_excited[:n]))

print(f'X shape: {X.shape}, y shape: {y.shape}')

# number of input columns
n_inputs = X.shape[1]

# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# scale data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print(f'X_train shape: {X_train.shape}, y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}, y_test shape: {y_test.shape}')
# Out:
# X shape: (900, 40), y shape: (900, 40)
# X_train shape: (720, 40), y_train shape: (720, 40)
# X_test shape: (180, 40), y_test shape: (180, 40)

# %% [markdown]
# ##### 2. Define autoencoder architecture

# %%
visible = Input(shape=(n_inputs,))
# encoder level 1
e = Dense(n_inputs*5/6)(visible)
e = BatchNormalization()(e)
e = LeakyReLU()(e)
# encoder level 2
e = Dense(n_inputs*4/6)(e)
e = BatchNormalization()(e)
e = LeakyReLU()(e)
# bottleneck
n_bottleneck = int (n_inputs/2)
bottleneck = Dense(n_bottleneck)(e)
# define decoder, level 1
d = Dense(n_inputs*4/6)(bottleneck)
d = BatchNormalization()(d)
d = LeakyReLU()(d)
# decoder level 2
d = Dense(n_inputs*5/6)(d)
d = BatchNormalization()(d)
d = LeakyReLU()(d)
# output layer
output = Dense(n_inputs, activation='linear')(d)
# define autoencoder model
model = Model(inputs=visible, outputs=output)

# %% [markdown]
# ##### 3. Train the model

# %%
import datetime
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, X_train, epochs=400, batch_size=32, verbose=2, validation_data=(X_test,X_test))
model.save(f'models/denoising_autoencoder_{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}.h5')
# Out:
# Epoch 1/400
# 23/23 - 2s - loss: 1.1084 - val_loss: 0.9130 - 2s/epoch - 77ms/step
# Epoch 2/400
# 23/23 - 0s - loss: 0.6652 - val_loss: 0.6731 - 106ms/epoch - 5ms/step
# Epoch 3/400
# 23/23 - 0s - loss: 0.4686 - val_loss: 0.4896 - 111ms/epoch - 5ms/step
# Epoch 4/400
# 23/23 - 0s - loss: 0.3641 - val_loss: 0.3672 - 98ms/epoch - 4ms/step
# Epoch 5/400
# 23/23 - 0s - loss: 0.3053 - val_loss: 0.2899 - 99ms/epoch - 4ms/step
# Epoch 6/400
# 23/23 - 0s - loss: 0.2840 - val_loss: 0.2363 - 92ms/epoch - 4ms/step
# Epoch 7/400
# 23/23 - 0s - loss: 0.2519 - val_loss: 0.2056 - 90ms/epoch - 4ms/step
# Epoch 8/400
# 23/23 - 0s - loss: 0.2324 - val_loss: 0.1841 - 91ms/epoch - 4ms/step
# Epoch 9/400
# 23/23 - 0s - loss: 0.2164 - val_loss: 0.1686 - 99ms/epoch - 4ms/step
# Epoch 10/400
# 23/23 - 0s - loss: 0.2088 - val_loss: 0.1598 - 101ms/epoch - 4ms/step
# Epoch 11/400
# 23/23 - 0s - loss: 0.2081 - val_loss: 0.1503 - 107ms/epoch - 5ms/step
# Epoch 12/400
# 23/23 - 0s - loss: 0.1938 - val_loss: 0.1459 - 100ms/epoch - 4ms/step
# Epoch 13/400
# 23/23 - 0s - loss: 0.1855 - val_loss: 0.1372 - 125ms/epoch - 5ms/step
# Epoch 14/400
# 23/23 - 0s - loss: 0.1832 - val_loss: 0.1317 - 115ms/epoch - 5ms/step
# Epoch 15/400
# 23/23 - 0s - loss: 0.1796 - val_loss: 0.1248 - 162ms/epoch - 7ms/step
# Epoch 16/400
# 23/23 - 0s - loss: 0.1673 - val_loss: 0.1226 - 128ms/epoch - 6ms/step
# Epoch 17/400
# 23/23 - 0s - loss: 0.1649 - val_loss: 0.1165 - 90ms/epoch - 4ms/step
# Epoch 18/400
# 23/23 - 0s - loss: 0.1682 - val_loss: 0.1124 - 92ms/epoch - 4ms/step
# Epoch 19/400
# 23/23 - 0s - loss: 0.1663 - val_loss: 0.1099 - 103ms/epoch - 4ms/step
# Epoch 20/400
# 23/23 - 0s - loss: 0.1657 - val_loss: 0.1057 - 106ms/epoch - 5ms/step
# Epoch 21/400
# 23/23 - 0s - loss: 0.1601 - val_loss: 0.1055 - 114ms/epoch - 5ms/step
# Epoch 22/400
# 23/23 - 0s - loss: 0.1586 - val_loss: 0.1020 - 117ms/epoch - 5ms/step
# Epoch 23/400
# 23/23 - 0s - loss: 0.1591 - val_loss: 0.1015 - 113ms/epoch - 5ms/step
# Epoch 24/400
# 23/23 - 0s - loss: 0.1439 - val_loss: 0.0983 - 107ms/epoch - 5ms/step
# Epoch 25/400
# 23/23 - 0s - loss: 0.1450 - val_loss: 0.0957 - 99ms/epoch - 4ms/step
# Epoch 26/400
# 23/23 - 0s - loss: 0.1428 - val_loss: 0.0936 - 87ms/epoch - 4ms/step
# Epoch 27/400
# 23/23 - 0s - loss: 0.1371 - val_loss: 0.0931 - 90ms/epoch - 4ms/step
# Epoch 28/400
# 23/23 - 0s - loss: 0.1324 - val_loss: 0.0925 - 130ms/epoch - 6ms/step
# Epoch 29/400
# 23/23 - 0s - loss: 0.1343 - val_loss: 0.0879 - 109ms/epoch - 5ms/step
# Epoch 30/400
# 23/23 - 0s - loss: 0.1443 - val_loss: 0.0875 - 90ms/epoch - 4ms/step
# Epoch 31/400
# 23/23 - 0s - loss: 0.1459 - val_loss: 0.0857 - 93ms/epoch - 4ms/step
# Epoch 32/400
# 23/23 - 0s - loss: 0.1323 - val_loss: 0.0848 - 90ms/epoch - 4ms/step
# Epoch 33/400
# 23/23 - 0s - loss: 0.1325 - val_loss: 0.0847 - 100ms/epoch - 4ms/step
# Epoch 34/400
# 23/23 - 0s - loss: 0.1300 - val_loss: 0.0821 - 110ms/epoch - 5ms/step
# Epoch 35/400
# 23/23 - 0s - loss: 0.1310 - val_loss: 0.0812 - 100ms/epoch - 4ms/step
# Epoch 36/400
# 23/23 - 0s - loss: 0.1289 - val_loss: 0.0804 - 100ms/epoch - 4ms/step
# Epoch 37/400
# 23/23 - 0s - loss: 0.1279 - val_loss: 0.0789 - 101ms/epoch - 4ms/step
# Epoch 38/400
# 23/23 - 0s - loss: 0.1239 - val_loss: 0.0774 - 109ms/epoch - 5ms/step
# Epoch 39/400
# 23/23 - 0s - loss: 0.1296 - val_loss: 0.0772 - 103ms/epoch - 4ms/step
# Epoch 40/400
# 23/23 - 0s - loss: 0.1282 - val_loss: 0.0765 - 107ms/epoch - 5ms/step
# Epoch 41/400
# 23/23 - 0s - loss: 0.1228 - val_loss: 0.0746 - 100ms/epoch - 4ms/step
# Epoch 42/400
# 23/23 - 0s - loss: 0.1197 - val_loss: 0.0747 - 110ms/epoch - 5ms/step
# Epoch 43/400
# 23/23 - 0s - loss: 0.1297 - val_loss: 0.0749 - 100ms/epoch - 4ms/step
# Epoch 44/400
# 23/23 - 0s - loss: 0.1169 - val_loss: 0.0733 - 100ms/epoch - 4ms/step
# Epoch 45/400
# 23/23 - 0s - loss: 0.1190 - val_loss: 0.0741 - 107ms/epoch - 5ms/step
# Epoch 46/400
# 23/23 - 0s - loss: 0.1276 - val_loss: 0.0735 - 110ms/epoch - 5ms/step
# Epoch 47/400
# 23/23 - 0s - loss: 0.1225 - val_loss: 0.0701 - 101ms/epoch - 4ms/step
# Epoch 48/400
# 23/23 - 0s - loss: 0.1169 - val_loss: 0.0714 - 106ms/epoch - 5ms/step
# Epoch 49/400
# 23/23 - 0s - loss: 0.1207 - val_loss: 0.0700 - 125ms/epoch - 5ms/step
# Epoch 50/400
# 23/23 - 0s - loss: 0.1212 - val_loss: 0.0722 - 103ms/epoch - 4ms/step
# Epoch 51/400
# 23/23 - 0s - loss: 0.1132 - val_loss: 0.0688 - 100ms/epoch - 4ms/step
# Epoch 52/400
# 23/23 - 0s - loss: 0.1136 - val_loss: 0.0672 - 103ms/epoch - 4ms/step
# Epoch 53/400
# 23/23 - 0s - loss: 0.1132 - val_loss: 0.0691 - 97ms/epoch - 4ms/step
# Epoch 54/400
# 23/23 - 0s - loss: 0.1094 - val_loss: 0.0678 - 100ms/epoch - 4ms/step
# Epoch 55/400
# 23/23 - 0s - loss: 0.1087 - val_loss: 0.0668 - 100ms/epoch - 4ms/step
# Epoch 56/400
# 23/23 - 0s - loss: 0.1183 - val_loss: 0.0665 - 100ms/epoch - 4ms/step
# Epoch 57/400
# 23/23 - 0s - loss: 0.1163 - val_loss: 0.0660 - 100ms/epoch - 4ms/step
# Epoch 58/400
# 23/23 - 0s - loss: 0.1202 - val_loss: 0.0672 - 93ms/epoch - 4ms/step
# Epoch 59/400
# 23/23 - 0s - loss: 0.1142 - val_loss: 0.0653 - 102ms/epoch - 4ms/step
# Epoch 60/400
# 23/23 - 0s - loss: 0.1055 - val_loss: 0.0655 - 105ms/epoch - 5ms/step
# Epoch 61/400
# 23/23 - 0s - loss: 0.1122 - val_loss: 0.0654 - 101ms/epoch - 4ms/step
# Epoch 62/400
# 23/23 - 0s - loss: 0.1085 - val_loss: 0.0636 - 91ms/epoch - 4ms/step
# Epoch 63/400
# 23/23 - 0s - loss: 0.1091 - val_loss: 0.0639 - 104ms/epoch - 5ms/step
# Epoch 64/400
# 23/23 - 0s - loss: 0.1040 - val_loss: 0.0631 - 100ms/epoch - 4ms/step
# Epoch 65/400
# 23/23 - 0s - loss: 0.1154 - val_loss: 0.0638 - 93ms/epoch - 4ms/step
# Epoch 66/400
# 23/23 - 0s - loss: 0.1077 - val_loss: 0.0620 - 106ms/epoch - 5ms/step
# Epoch 67/400
# 23/23 - 0s - loss: 0.1063 - val_loss: 0.0607 - 106ms/epoch - 5ms/step
# Epoch 68/400
# 23/23 - 0s - loss: 0.1014 - val_loss: 0.0619 - 104ms/epoch - 5ms/step
# Epoch 69/400
# 23/23 - 0s - loss: 0.1067 - val_loss: 0.0615 - 107ms/epoch - 5ms/step
# Epoch 70/400
# 23/23 - 0s - loss: 0.1097 - val_loss: 0.0610 - 108ms/epoch - 5ms/step
# Epoch 71/400
# 23/23 - 0s - loss: 0.1001 - val_loss: 0.0620 - 101ms/epoch - 4ms/step
# Epoch 72/400
# 23/23 - 0s - loss: 0.1050 - val_loss: 0.0614 - 104ms/epoch - 5ms/step
# Epoch 73/400
# 23/23 - 0s - loss: 0.1136 - val_loss: 0.0605 - 104ms/epoch - 5ms/step
# Epoch 74/400
# 23/23 - 0s - loss: 0.0997 - val_loss: 0.0601 - 100ms/epoch - 4ms/step
# Epoch 75/400
# 23/23 - 0s - loss: 0.1096 - val_loss: 0.0595 - 106ms/epoch - 5ms/step
# Epoch 76/400
# 23/23 - 0s - loss: 0.0977 - val_loss: 0.0580 - 94ms/epoch - 4ms/step
# Epoch 77/400
# 23/23 - 0s - loss: 0.1006 - val_loss: 0.0589 - 114ms/epoch - 5ms/step
# Epoch 78/400
# 23/23 - 0s - loss: 0.1050 - val_loss: 0.0581 - 100ms/epoch - 4ms/step
# Epoch 79/400
# 23/23 - 0s - loss: 0.1061 - val_loss: 0.0576 - 100ms/epoch - 4ms/step
# Epoch 80/400
# 23/23 - 0s - loss: 0.0993 - val_loss: 0.0572 - 116ms/epoch - 5ms/step
# Epoch 81/400
# 23/23 - 0s - loss: 0.1068 - val_loss: 0.0589 - 101ms/epoch - 4ms/step
# Epoch 82/400
# 23/23 - 0s - loss: 0.1064 - val_loss: 0.0574 - 100ms/epoch - 4ms/step
# Epoch 83/400
# 23/23 - 0s - loss: 0.0995 - val_loss: 0.0573 - 107ms/epoch - 5ms/step
# Epoch 84/400
# 23/23 - 0s - loss: 0.1075 - val_loss: 0.0579 - 109ms/epoch - 5ms/step
# Epoch 85/400
# 23/23 - 0s - loss: 0.0932 - val_loss: 0.0568 - 100ms/epoch - 4ms/step
# Epoch 86/400
# 23/23 - 0s - loss: 0.0967 - val_loss: 0.0558 - 108ms/epoch - 5ms/step
# Epoch 87/400
# 23/23 - 0s - loss: 0.0949 - val_loss: 0.0560 - 104ms/epoch - 5ms/step
# Epoch 88/400
# 23/23 - 0s - loss: 0.1058 - val_loss: 0.0565 - 106ms/epoch - 5ms/step
# Epoch 89/400
# 23/23 - 0s - loss: 0.0952 - val_loss: 0.0556 - 103ms/epoch - 4ms/step
# Epoch 90/400
# 23/23 - 0s - loss: 0.1003 - val_loss: 0.0549 - 102ms/epoch - 4ms/step
# Epoch 91/400
# 23/23 - 0s - loss: 0.0966 - val_loss: 0.0557 - 92ms/epoch - 4ms/step
# Epoch 92/400
# 23/23 - 0s - loss: 0.1031 - val_loss: 0.0547 - 106ms/epoch - 5ms/step
# Epoch 93/400
# 23/23 - 0s - loss: 0.0979 - val_loss: 0.0537 - 100ms/epoch - 4ms/step
# Epoch 94/400
# 23/23 - 0s - loss: 0.0912 - val_loss: 0.0540 - 99ms/epoch - 4ms/step
# Epoch 95/400
# 23/23 - 0s - loss: 0.0889 - val_loss: 0.0546 - 104ms/epoch - 5ms/step
# Epoch 96/400
# 23/23 - 0s - loss: 0.0997 - val_loss: 0.0534 - 99ms/epoch - 4ms/step
# Epoch 97/400
# 23/23 - 0s - loss: 0.0966 - val_loss: 0.0536 - 98ms/epoch - 4ms/step
# Epoch 98/400
# 23/23 - 0s - loss: 0.0944 - val_loss: 0.0532 - 108ms/epoch - 5ms/step
# Epoch 99/400
# 23/23 - 0s - loss: 0.0885 - val_loss: 0.0535 - 104ms/epoch - 5ms/step
# Epoch 100/400
# 23/23 - 0s - loss: 0.0968 - val_loss: 0.0523 - 101ms/epoch - 4ms/step
# Epoch 101/400
# 23/23 - 0s - loss: 0.0920 - val_loss: 0.0522 - 98ms/epoch - 4ms/step
# Epoch 102/400
# 23/23 - 0s - loss: 0.0915 - val_loss: 0.0530 - 111ms/epoch - 5ms/step
# Epoch 103/400
# 23/23 - 0s - loss: 0.0854 - val_loss: 0.0521 - 100ms/epoch - 4ms/step
# Epoch 104/400
# 23/23 - 0s - loss: 0.1037 - val_loss: 0.0517 - 100ms/epoch - 4ms/step
# Epoch 105/400
# 23/23 - 0s - loss: 0.0978 - val_loss: 0.0523 - 117ms/epoch - 5ms/step
# Epoch 106/400
# 23/23 - 0s - loss: 0.0959 - val_loss: 0.0517 - 100ms/epoch - 4ms/step
# Epoch 107/400
# 23/23 - 0s - loss: 0.1009 - val_loss: 0.0534 - 100ms/epoch - 4ms/step
# Epoch 108/400
# 23/23 - 0s - loss: 0.0983 - val_loss: 0.0517 - 117ms/epoch - 5ms/step
# Epoch 109/400
# 23/23 - 0s - loss: 0.0969 - val_loss: 0.0518 - 100ms/epoch - 4ms/step
# Epoch 110/400
# 23/23 - 0s - loss: 0.0975 - val_loss: 0.0521 - 95ms/epoch - 4ms/step
# Epoch 111/400
# 23/23 - 0s - loss: 0.0897 - val_loss: 0.0511 - 109ms/epoch - 5ms/step
# Epoch 112/400
# 23/23 - 0s - loss: 0.0988 - val_loss: 0.0504 - 110ms/epoch - 5ms/step
# Epoch 113/400
# 23/23 - 0s - loss: 0.0889 - val_loss: 0.0516 - 95ms/epoch - 4ms/step
# Epoch 114/400
# 23/23 - 0s - loss: 0.0860 - val_loss: 0.0506 - 111ms/epoch - 5ms/step
# Epoch 115/400
# 23/23 - 0s - loss: 0.0964 - val_loss: 0.0494 - 99ms/epoch - 4ms/step
# Epoch 116/400
# 23/23 - 0s - loss: 0.0873 - val_loss: 0.0503 - 95ms/epoch - 4ms/step
# Epoch 117/400
# 23/23 - 0s - loss: 0.1044 - val_loss: 0.0505 - 104ms/epoch - 5ms/step
# Epoch 118/400
# 23/23 - 0s - loss: 0.0975 - val_loss: 0.0511 - 102ms/epoch - 4ms/step
# Epoch 119/400
# 23/23 - 0s - loss: 0.0811 - val_loss: 0.0495 - 101ms/epoch - 4ms/step
# Epoch 120/400
# 23/23 - 0s - loss: 0.0880 - val_loss: 0.0495 - 109ms/epoch - 5ms/step
# Epoch 121/400
# 23/23 - 0s - loss: 0.0860 - val_loss: 0.0493 - 92ms/epoch - 4ms/step
# Epoch 122/400
# 23/23 - 0s - loss: 0.0876 - val_loss: 0.0489 - 94ms/epoch - 4ms/step
# Epoch 123/400
# 23/23 - 0s - loss: 0.0889 - val_loss: 0.0497 - 95ms/epoch - 4ms/step
# Epoch 124/400
# 23/23 - 0s - loss: 0.1008 - val_loss: 0.0484 - 96ms/epoch - 4ms/step
# Epoch 125/400
# 23/23 - 0s - loss: 0.0912 - val_loss: 0.0490 - 104ms/epoch - 5ms/step
# Epoch 126/400
# 23/23 - 0s - loss: 0.0949 - val_loss: 0.0486 - 100ms/epoch - 4ms/step
# Epoch 127/400
# 23/23 - 0s - loss: 0.0863 - val_loss: 0.0476 - 105ms/epoch - 5ms/step
# Epoch 128/400
# 23/23 - 0s - loss: 0.0878 - val_loss: 0.0480 - 117ms/epoch - 5ms/step
# Epoch 129/400
# 23/23 - 0s - loss: 0.0992 - val_loss: 0.0480 - 109ms/epoch - 5ms/step
# Epoch 130/400
# 23/23 - 0s - loss: 0.0841 - val_loss: 0.0470 - 108ms/epoch - 5ms/step
# Epoch 131/400
# 23/23 - 0s - loss: 0.0951 - val_loss: 0.0480 - 99ms/epoch - 4ms/step
# Epoch 132/400
# 23/23 - 0s - loss: 0.0935 - val_loss: 0.0473 - 128ms/epoch - 6ms/step
# Epoch 133/400
# 23/23 - 0s - loss: 0.0940 - val_loss: 0.0471 - 117ms/epoch - 5ms/step
# Epoch 134/400
# 23/23 - 0s - loss: 0.0876 - val_loss: 0.0475 - 123ms/epoch - 5ms/step
# Epoch 135/400
# 23/23 - 0s - loss: 0.0824 - val_loss: 0.0468 - 110ms/epoch - 5ms/step
# Epoch 136/400
# 23/23 - 0s - loss: 0.0901 - val_loss: 0.0470 - 106ms/epoch - 5ms/step
# Epoch 137/400
# 23/23 - 0s - loss: 0.0933 - val_loss: 0.0476 - 102ms/epoch - 4ms/step
# Epoch 138/400
# 23/23 - 0s - loss: 0.0808 - val_loss: 0.0454 - 98ms/epoch - 4ms/step
# Epoch 139/400
# 23/23 - 0s - loss: 0.0948 - val_loss: 0.0467 - 101ms/epoch - 4ms/step
# Epoch 140/400
# 23/23 - 0s - loss: 0.0816 - val_loss: 0.0464 - 91ms/epoch - 4ms/step
# Epoch 141/400
# 23/23 - 0s - loss: 0.0887 - val_loss: 0.0458 - 100ms/epoch - 4ms/step
# Epoch 142/400
# 23/23 - 0s - loss: 0.0895 - val_loss: 0.0459 - 87ms/epoch - 4ms/step
# Epoch 143/400
# 23/23 - 0s - loss: 0.0813 - val_loss: 0.0455 - 100ms/epoch - 4ms/step
# Epoch 144/400
# 23/23 - 0s - loss: 0.0893 - val_loss: 0.0462 - 100ms/epoch - 4ms/step
# Epoch 145/400
# 23/23 - 0s - loss: 0.0884 - val_loss: 0.0458 - 116ms/epoch - 5ms/step
# Epoch 146/400
# 23/23 - 0s - loss: 0.0848 - val_loss: 0.0453 - 102ms/epoch - 4ms/step
# Epoch 147/400
# 23/23 - 0s - loss: 0.0812 - val_loss: 0.0452 - 100ms/epoch - 4ms/step
# Epoch 148/400
# 23/23 - 0s - loss: 0.0841 - val_loss: 0.0458 - 99ms/epoch - 4ms/step
# Epoch 149/400
# 23/23 - 0s - loss: 0.0889 - val_loss: 0.0452 - 101ms/epoch - 4ms/step
# Epoch 150/400
# 23/23 - 0s - loss: 0.0756 - val_loss: 0.0446 - 100ms/epoch - 4ms/step
# Epoch 151/400
# 23/23 - 0s - loss: 0.0874 - val_loss: 0.0457 - 104ms/epoch - 5ms/step
# Epoch 152/400
# 23/23 - 0s - loss: 0.0820 - val_loss: 0.0448 - 87ms/epoch - 4ms/step
# Epoch 153/400
# 23/23 - 0s - loss: 0.0815 - val_loss: 0.0440 - 100ms/epoch - 4ms/step
# Epoch 154/400
# 23/23 - 0s - loss: 0.0810 - val_loss: 0.0448 - 97ms/epoch - 4ms/step
# Epoch 155/400
# 23/23 - 0s - loss: 0.0844 - val_loss: 0.0453 - 83ms/epoch - 4ms/step
# Epoch 156/400
# 23/23 - 0s - loss: 0.0813 - val_loss: 0.0430 - 99ms/epoch - 4ms/step
# Epoch 157/400
# 23/23 - 0s - loss: 0.0811 - val_loss: 0.0436 - 89ms/epoch - 4ms/step
# Epoch 158/400
# 23/23 - 0s - loss: 0.0757 - val_loss: 0.0424 - 90ms/epoch - 4ms/step
# Epoch 159/400
# 23/23 - 0s - loss: 0.0933 - val_loss: 0.0437 - 91ms/epoch - 4ms/step
# Epoch 160/400
# 23/23 - 0s - loss: 0.0893 - val_loss: 0.0461 - 100ms/epoch - 4ms/step
# Epoch 161/400
# 23/23 - 0s - loss: 0.0829 - val_loss: 0.0429 - 99ms/epoch - 4ms/step
# Epoch 162/400
# 23/23 - 0s - loss: 0.0852 - val_loss: 0.0438 - 96ms/epoch - 4ms/step
# Epoch 163/400
# 23/23 - 0s - loss: 0.0802 - val_loss: 0.0420 - 133ms/epoch - 6ms/step
# Epoch 164/400
# 23/23 - 0s - loss: 0.0874 - val_loss: 0.0432 - 120ms/epoch - 5ms/step
# Epoch 165/400
# 23/23 - 0s - loss: 0.0797 - val_loss: 0.0426 - 112ms/epoch - 5ms/step
# Epoch 166/400
# 23/23 - 0s - loss: 0.0874 - val_loss: 0.0431 - 112ms/epoch - 5ms/step
# Epoch 167/400
# 23/23 - 0s - loss: 0.0865 - val_loss: 0.0437 - 108ms/epoch - 5ms/step
# Epoch 168/400
# 23/23 - 0s - loss: 0.0895 - val_loss: 0.0423 - 96ms/epoch - 4ms/step
# Epoch 169/400
# 23/23 - 0s - loss: 0.0815 - val_loss: 0.0421 - 104ms/epoch - 5ms/step
# Epoch 170/400
# 23/23 - 0s - loss: 0.0807 - val_loss: 0.0419 - 102ms/epoch - 4ms/step
# Epoch 171/400
# 23/23 - 0s - loss: 0.0845 - val_loss: 0.0417 - 98ms/epoch - 4ms/step
# Epoch 172/400
# 23/23 - 0s - loss: 0.0772 - val_loss: 0.0420 - 102ms/epoch - 4ms/step
# Epoch 173/400
# 23/23 - 0s - loss: 0.0773 - val_loss: 0.0411 - 99ms/epoch - 4ms/step
# Epoch 174/400
# 23/23 - 0s - loss: 0.0875 - val_loss: 0.0420 - 96ms/epoch - 4ms/step
# Epoch 175/400
# 23/23 - 0s - loss: 0.0847 - val_loss: 0.0415 - 91ms/epoch - 4ms/step
# Epoch 176/400
# 23/23 - 0s - loss: 0.0904 - val_loss: 0.0426 - 106ms/epoch - 5ms/step
# Epoch 177/400
# 23/23 - 0s - loss: 0.0795 - val_loss: 0.0423 - 99ms/epoch - 4ms/step
# Epoch 178/400
# 23/23 - 0s - loss: 0.0826 - val_loss: 0.0413 - 104ms/epoch - 5ms/step
# Epoch 179/400
# 23/23 - 0s - loss: 0.0893 - val_loss: 0.0411 - 125ms/epoch - 5ms/step
# Epoch 180/400
# 23/23 - 0s - loss: 0.0735 - val_loss: 0.0398 - 198ms/epoch - 9ms/step
# Epoch 181/400
# 23/23 - 0s - loss: 0.0842 - val_loss: 0.0406 - 222ms/epoch - 10ms/step
# Epoch 182/400
# 23/23 - 0s - loss: 0.0775 - val_loss: 0.0402 - 114ms/epoch - 5ms/step
# Epoch 183/400
# 23/23 - 0s - loss: 0.0880 - val_loss: 0.0402 - 117ms/epoch - 5ms/step
# Epoch 184/400
# 23/23 - 0s - loss: 0.0856 - val_loss: 0.0406 - 115ms/epoch - 5ms/step
# Epoch 185/400
# 23/23 - 0s - loss: 0.0796 - val_loss: 0.0408 - 194ms/epoch - 8ms/step
# Epoch 186/400
# 23/23 - 0s - loss: 0.0774 - val_loss: 0.0404 - 122ms/epoch - 5ms/step
# Epoch 187/400
# 23/23 - 0s - loss: 0.0849 - val_loss: 0.0400 - 132ms/epoch - 6ms/step
# Epoch 188/400
# 23/23 - 0s - loss: 0.0742 - val_loss: 0.0392 - 134ms/epoch - 6ms/step
# Epoch 189/400
# 23/23 - 0s - loss: 0.0798 - val_loss: 0.0394 - 143ms/epoch - 6ms/step
# Epoch 190/400
# 23/23 - 0s - loss: 0.0755 - val_loss: 0.0403 - 158ms/epoch - 7ms/step
# Epoch 191/400
# 23/23 - 0s - loss: 0.0800 - val_loss: 0.0387 - 134ms/epoch - 6ms/step
# Epoch 192/400
# 23/23 - 0s - loss: 0.0763 - val_loss: 0.0399 - 133ms/epoch - 6ms/step
# Epoch 193/400
# 23/23 - 0s - loss: 0.0861 - val_loss: 0.0390 - 122ms/epoch - 5ms/step
# Epoch 194/400
# 23/23 - 0s - loss: 0.0865 - val_loss: 0.0397 - 125ms/epoch - 5ms/step
# Epoch 195/400
# 23/23 - 0s - loss: 0.0785 - val_loss: 0.0388 - 114ms/epoch - 5ms/step
# Epoch 196/400
# 23/23 - 0s - loss: 0.0786 - val_loss: 0.0403 - 116ms/epoch - 5ms/step
# Epoch 197/400
# 23/23 - 0s - loss: 0.0796 - val_loss: 0.0388 - 133ms/epoch - 6ms/step
# Epoch 198/400
# 23/23 - 0s - loss: 0.0829 - val_loss: 0.0395 - 140ms/epoch - 6ms/step
# Epoch 199/400
# 23/23 - 0s - loss: 0.0790 - val_loss: 0.0388 - 143ms/epoch - 6ms/step
# Epoch 200/400
# 23/23 - 0s - loss: 0.0792 - val_loss: 0.0383 - 133ms/epoch - 6ms/step
# Epoch 201/400
# 23/23 - 0s - loss: 0.0729 - val_loss: 0.0381 - 112ms/epoch - 5ms/step
# Epoch 202/400
# 23/23 - 0s - loss: 0.0750 - val_loss: 0.0383 - 120ms/epoch - 5ms/step
# Epoch 203/400
# 23/23 - 0s - loss: 0.0851 - val_loss: 0.0391 - 117ms/epoch - 5ms/step
# Epoch 204/400
# 23/23 - 0s - loss: 0.0753 - val_loss: 0.0382 - 100ms/epoch - 4ms/step
# Epoch 205/400
# 23/23 - 0s - loss: 0.0746 - val_loss: 0.0394 - 105ms/epoch - 5ms/step
# Epoch 206/400
# 23/23 - 0s - loss: 0.0848 - val_loss: 0.0400 - 111ms/epoch - 5ms/step
# Epoch 207/400
# 23/23 - 0s - loss: 0.0809 - val_loss: 0.0380 - 90ms/epoch - 4ms/step
# Epoch 208/400
# 23/23 - 0s - loss: 0.0780 - val_loss: 0.0394 - 93ms/epoch - 4ms/step
# Epoch 209/400
# 23/23 - 0s - loss: 0.0784 - val_loss: 0.0390 - 94ms/epoch - 4ms/step
# Epoch 210/400
# 23/23 - 0s - loss: 0.0733 - val_loss: 0.0375 - 97ms/epoch - 4ms/step
# Epoch 211/400
# 23/23 - 0s - loss: 0.0770 - val_loss: 0.0376 - 101ms/epoch - 4ms/step
# Epoch 212/400
# 23/23 - 0s - loss: 0.0829 - val_loss: 0.0379 - 97ms/epoch - 4ms/step
# Epoch 213/400
# 23/23 - 0s - loss: 0.0755 - val_loss: 0.0383 - 125ms/epoch - 5ms/step
# Epoch 214/400
# 23/23 - 0s - loss: 0.0828 - val_loss: 0.0385 - 123ms/epoch - 5ms/step
# Epoch 215/400
# 23/23 - 0s - loss: 0.0829 - val_loss: 0.0389 - 106ms/epoch - 5ms/step
# Epoch 216/400
# 23/23 - 0s - loss: 0.0856 - val_loss: 0.0374 - 99ms/epoch - 4ms/step
# Epoch 217/400
# 23/23 - 0s - loss: 0.0833 - val_loss: 0.0368 - 103ms/epoch - 4ms/step
# Epoch 218/400
# 23/23 - 0s - loss: 0.0810 - val_loss: 0.0372 - 104ms/epoch - 5ms/step
# Epoch 219/400
# 23/23 - 0s - loss: 0.0730 - val_loss: 0.0365 - 108ms/epoch - 5ms/step
# Epoch 220/400
# 23/23 - 0s - loss: 0.0755 - val_loss: 0.0382 - 92ms/epoch - 4ms/step
# Epoch 221/400
# 23/23 - 0s - loss: 0.0795 - val_loss: 0.0360 - 95ms/epoch - 4ms/step
# Epoch 222/400
# 23/23 - 0s - loss: 0.0807 - val_loss: 0.0368 - 107ms/epoch - 5ms/step
# Epoch 223/400
# 23/23 - 0s - loss: 0.0791 - val_loss: 0.0375 - 104ms/epoch - 5ms/step
# Epoch 224/400
# 23/23 - 0s - loss: 0.0728 - val_loss: 0.0367 - 102ms/epoch - 4ms/step
# Epoch 225/400
# 23/23 - 0s - loss: 0.0795 - val_loss: 0.0360 - 102ms/epoch - 4ms/step
# Epoch 226/400
# 23/23 - 0s - loss: 0.0871 - val_loss: 0.0371 - 101ms/epoch - 4ms/step
# Epoch 227/400
# 23/23 - 0s - loss: 0.0709 - val_loss: 0.0364 - 96ms/epoch - 4ms/step
# Epoch 228/400
# 23/23 - 0s - loss: 0.0742 - val_loss: 0.0360 - 99ms/epoch - 4ms/step
# Epoch 229/400
# 23/23 - 0s - loss: 0.0703 - val_loss: 0.0359 - 100ms/epoch - 4ms/step
# Epoch 230/400
# 23/23 - 0s - loss: 0.0684 - val_loss: 0.0370 - 103ms/epoch - 4ms/step
# Epoch 231/400
# 23/23 - 0s - loss: 0.0756 - val_loss: 0.0357 - 96ms/epoch - 4ms/step
# Epoch 232/400
# 23/23 - 0s - loss: 0.0763 - val_loss: 0.0361 - 98ms/epoch - 4ms/step
# Epoch 233/400
# 23/23 - 0s - loss: 0.0742 - val_loss: 0.0366 - 81ms/epoch - 4ms/step
# Epoch 234/400
# 23/23 - 0s - loss: 0.0813 - val_loss: 0.0368 - 87ms/epoch - 4ms/step
# Epoch 235/400
# 23/23 - 0s - loss: 0.0739 - val_loss: 0.0350 - 97ms/epoch - 4ms/step
# Epoch 236/400
# 23/23 - 0s - loss: 0.0762 - val_loss: 0.0361 - 86ms/epoch - 4ms/step
# Epoch 237/400
# 23/23 - 0s - loss: 0.0693 - val_loss: 0.0354 - 99ms/epoch - 4ms/step
# Epoch 238/400
# 23/23 - 0s - loss: 0.0703 - val_loss: 0.0357 - 92ms/epoch - 4ms/step
# Epoch 239/400
# 23/23 - 0s - loss: 0.0789 - val_loss: 0.0353 - 86ms/epoch - 4ms/step
# Epoch 240/400
# 23/23 - 0s - loss: 0.0772 - val_loss: 0.0356 - 101ms/epoch - 4ms/step
# Epoch 241/400
# 23/23 - 0s - loss: 0.0799 - val_loss: 0.0357 - 121ms/epoch - 5ms/step
# Epoch 242/400
# 23/23 - 0s - loss: 0.0677 - val_loss: 0.0350 - 125ms/epoch - 5ms/step
# Epoch 243/400
# 23/23 - 0s - loss: 0.0770 - val_loss: 0.0357 - 134ms/epoch - 6ms/step
# Epoch 244/400
# 23/23 - 0s - loss: 0.0768 - val_loss: 0.0348 - 183ms/epoch - 8ms/step
# Epoch 245/400
# 23/23 - 0s - loss: 0.0715 - val_loss: 0.0353 - 174ms/epoch - 8ms/step
# Epoch 246/400
# 23/23 - 0s - loss: 0.0785 - val_loss: 0.0350 - 172ms/epoch - 7ms/step
# Epoch 247/400
# 23/23 - 0s - loss: 0.0790 - val_loss: 0.0347 - 168ms/epoch - 7ms/step
# Epoch 248/400
# 23/23 - 0s - loss: 0.0836 - val_loss: 0.0360 - 166ms/epoch - 7ms/step
# Epoch 249/400
# 23/23 - 0s - loss: 0.0701 - val_loss: 0.0350 - 150ms/epoch - 7ms/step
# Epoch 250/400
# 23/23 - 0s - loss: 0.0826 - val_loss: 0.0358 - 145ms/epoch - 6ms/step
# Epoch 251/400
# 23/23 - 0s - loss: 0.0740 - val_loss: 0.0363 - 150ms/epoch - 7ms/step
# Epoch 252/400
# 23/23 - 0s - loss: 0.0755 - val_loss: 0.0354 - 149ms/epoch - 6ms/step
# Epoch 253/400
# 23/23 - 0s - loss: 0.0764 - val_loss: 0.0354 - 151ms/epoch - 7ms/step
# Epoch 254/400
# 23/23 - 0s - loss: 0.0687 - val_loss: 0.0345 - 149ms/epoch - 6ms/step
# Epoch 255/400
# 23/23 - 0s - loss: 0.0688 - val_loss: 0.0345 - 143ms/epoch - 6ms/step
# Epoch 256/400
# 23/23 - 0s - loss: 0.0655 - val_loss: 0.0341 - 128ms/epoch - 6ms/step
# Epoch 257/400
# 23/23 - 0s - loss: 0.0868 - val_loss: 0.0359 - 134ms/epoch - 6ms/step
# Epoch 258/400
# 23/23 - 0s - loss: 0.0642 - val_loss: 0.0340 - 115ms/epoch - 5ms/step
# Epoch 259/400
# 23/23 - 0s - loss: 0.0792 - val_loss: 0.0344 - 117ms/epoch - 5ms/step
# Epoch 260/400
# 23/23 - 0s - loss: 0.0758 - val_loss: 0.0356 - 134ms/epoch - 6ms/step
# Epoch 261/400
# 23/23 - 0s - loss: 0.0790 - val_loss: 0.0352 - 122ms/epoch - 5ms/step
# Epoch 262/400
# 23/23 - 0s - loss: 0.0777 - val_loss: 0.0343 - 117ms/epoch - 5ms/step
# Epoch 263/400
# 23/23 - 0s - loss: 0.0693 - val_loss: 0.0340 - 125ms/epoch - 5ms/step
# Epoch 264/400
# 23/23 - 0s - loss: 0.0771 - val_loss: 0.0333 - 118ms/epoch - 5ms/step
# Epoch 265/400
# 23/23 - 0s - loss: 0.0741 - val_loss: 0.0351 - 127ms/epoch - 6ms/step
# Epoch 266/400
# 23/23 - 0s - loss: 0.0684 - val_loss: 0.0340 - 116ms/epoch - 5ms/step
# Epoch 267/400
# 23/23 - 0s - loss: 0.0703 - val_loss: 0.0347 - 123ms/epoch - 5ms/step
# Epoch 268/400
# 23/23 - 0s - loss: 0.0689 - val_loss: 0.0339 - 134ms/epoch - 6ms/step
# Epoch 269/400
# 23/23 - 0s - loss: 0.0758 - val_loss: 0.0334 - 140ms/epoch - 6ms/step
# Epoch 270/400
# 23/23 - 0s - loss: 0.0742 - val_loss: 0.0347 - 136ms/epoch - 6ms/step
# Epoch 271/400
# 23/23 - 0s - loss: 0.0803 - val_loss: 0.0354 - 146ms/epoch - 6ms/step
# Epoch 272/400
# 23/23 - 0s - loss: 0.0767 - val_loss: 0.0336 - 142ms/epoch - 6ms/step
# Epoch 273/400
# 23/23 - 0s - loss: 0.0895 - val_loss: 0.0346 - 136ms/epoch - 6ms/step
# Epoch 274/400
# 23/23 - 0s - loss: 0.0740 - val_loss: 0.0334 - 128ms/epoch - 6ms/step
# Epoch 275/400
# 23/23 - 0s - loss: 0.0666 - val_loss: 0.0351 - 134ms/epoch - 6ms/step
# Epoch 276/400
# 23/23 - 0s - loss: 0.0628 - val_loss: 0.0329 - 116ms/epoch - 5ms/step
# Epoch 277/400
# 23/23 - 0s - loss: 0.0691 - val_loss: 0.0328 - 129ms/epoch - 6ms/step
# Epoch 278/400
# 23/23 - 0s - loss: 0.0642 - val_loss: 0.0326 - 114ms/epoch - 5ms/step
# Epoch 279/400
# 23/23 - 0s - loss: 0.0730 - val_loss: 0.0337 - 116ms/epoch - 5ms/step
# Epoch 280/400
# 23/23 - 0s - loss: 0.0710 - val_loss: 0.0346 - 112ms/epoch - 5ms/step
# Epoch 281/400
# 23/23 - 0s - loss: 0.0741 - val_loss: 0.0336 - 107ms/epoch - 5ms/step
# Epoch 282/400
# 23/23 - 0s - loss: 0.0701 - val_loss: 0.0329 - 112ms/epoch - 5ms/step
# Epoch 283/400
# 23/23 - 0s - loss: 0.0675 - val_loss: 0.0339 - 106ms/epoch - 5ms/step
# Epoch 284/400
# 23/23 - 0s - loss: 0.0746 - val_loss: 0.0330 - 103ms/epoch - 4ms/step
# Epoch 285/400
# 23/23 - 0s - loss: 0.0835 - val_loss: 0.0335 - 118ms/epoch - 5ms/step
# Epoch 286/400
# 23/23 - 0s - loss: 0.0721 - val_loss: 0.0331 - 108ms/epoch - 5ms/step
# Epoch 287/400
# 23/23 - 0s - loss: 0.0698 - val_loss: 0.0326 - 100ms/epoch - 4ms/step
# Epoch 288/400
# 23/23 - 0s - loss: 0.0745 - val_loss: 0.0328 - 91ms/epoch - 4ms/step
# Epoch 289/400
# 23/23 - 0s - loss: 0.0695 - val_loss: 0.0328 - 91ms/epoch - 4ms/step
# Epoch 290/400
# 23/23 - 0s - loss: 0.0685 - val_loss: 0.0338 - 100ms/epoch - 4ms/step
# Epoch 291/400
# 23/23 - 0s - loss: 0.0711 - val_loss: 0.0327 - 100ms/epoch - 4ms/step
# Epoch 292/400
# 23/23 - 0s - loss: 0.0690 - val_loss: 0.0324 - 95ms/epoch - 4ms/step
# Epoch 293/400
# 23/23 - 0s - loss: 0.0739 - val_loss: 0.0326 - 107ms/epoch - 5ms/step
# Epoch 294/400
# 23/23 - 0s - loss: 0.0695 - val_loss: 0.0328 - 110ms/epoch - 5ms/step
# Epoch 295/400
# 23/23 - 0s - loss: 0.0809 - val_loss: 0.0338 - 104ms/epoch - 5ms/step
# Epoch 296/400
# 23/23 - 0s - loss: 0.0637 - val_loss: 0.0321 - 105ms/epoch - 5ms/step
# Epoch 297/400
# 23/23 - 0s - loss: 0.0731 - val_loss: 0.0344 - 103ms/epoch - 4ms/step
# Epoch 298/400
# 23/23 - 0s - loss: 0.0785 - val_loss: 0.0332 - 100ms/epoch - 4ms/step
# Epoch 299/400
# 23/23 - 0s - loss: 0.0750 - val_loss: 0.0321 - 106ms/epoch - 5ms/step
# Epoch 300/400
# 23/23 - 0s - loss: 0.0729 - val_loss: 0.0335 - 108ms/epoch - 5ms/step
# Epoch 301/400
# 23/23 - 0s - loss: 0.0693 - val_loss: 0.0319 - 132ms/epoch - 6ms/step
# Epoch 302/400
# 23/23 - 0s - loss: 0.0739 - val_loss: 0.0316 - 128ms/epoch - 6ms/step
# Epoch 303/400
# 23/23 - 0s - loss: 0.0667 - val_loss: 0.0325 - 122ms/epoch - 5ms/step
# Epoch 304/400
# 23/23 - 0s - loss: 0.0747 - val_loss: 0.0323 - 110ms/epoch - 5ms/step
# Epoch 305/400
# 23/23 - 0s - loss: 0.0691 - val_loss: 0.0318 - 109ms/epoch - 5ms/step
# Epoch 306/400
# 23/23 - 0s - loss: 0.0688 - val_loss: 0.0322 - 120ms/epoch - 5ms/step
# Epoch 307/400
# 23/23 - 0s - loss: 0.0719 - val_loss: 0.0325 - 101ms/epoch - 4ms/step
# Epoch 308/400
# 23/23 - 0s - loss: 0.0799 - val_loss: 0.0319 - 103ms/epoch - 4ms/step
# Epoch 309/400
# 23/23 - 0s - loss: 0.0701 - val_loss: 0.0320 - 100ms/epoch - 4ms/step
# Epoch 310/400
# 23/23 - 0s - loss: 0.0712 - val_loss: 0.0316 - 106ms/epoch - 5ms/step
# Epoch 311/400
# 23/23 - 0s - loss: 0.0623 - val_loss: 0.0317 - 100ms/epoch - 4ms/step
# Epoch 312/400
# 23/23 - 0s - loss: 0.0724 - val_loss: 0.0319 - 103ms/epoch - 4ms/step
# Epoch 313/400
# 23/23 - 0s - loss: 0.0781 - val_loss: 0.0319 - 97ms/epoch - 4ms/step
# Epoch 314/400
# 23/23 - 0s - loss: 0.0620 - val_loss: 0.0313 - 98ms/epoch - 4ms/step
# Epoch 315/400
# 23/23 - 0s - loss: 0.0656 - val_loss: 0.0315 - 97ms/epoch - 4ms/step
# Epoch 316/400
# 23/23 - 0s - loss: 0.0678 - val_loss: 0.0316 - 103ms/epoch - 4ms/step
# Epoch 317/400
# 23/23 - 0s - loss: 0.0663 - val_loss: 0.0315 - 104ms/epoch - 5ms/step
# Epoch 318/400
# 23/23 - 0s - loss: 0.0755 - val_loss: 0.0309 - 103ms/epoch - 4ms/step
# Epoch 319/400
# 23/23 - 0s - loss: 0.0713 - val_loss: 0.0318 - 97ms/epoch - 4ms/step
# Epoch 320/400
# 23/23 - 0s - loss: 0.0685 - val_loss: 0.0311 - 90ms/epoch - 4ms/step
# Epoch 321/400
# 23/23 - 0s - loss: 0.0701 - val_loss: 0.0312 - 86ms/epoch - 4ms/step
# Epoch 322/400
# 23/23 - 0s - loss: 0.0807 - val_loss: 0.0324 - 99ms/epoch - 4ms/step
# Epoch 323/400
# 23/23 - 0s - loss: 0.0783 - val_loss: 0.0314 - 81ms/epoch - 4ms/step
# Epoch 324/400
# 23/23 - 0s - loss: 0.0611 - val_loss: 0.0309 - 100ms/epoch - 4ms/step
# Epoch 325/400
# 23/23 - 0s - loss: 0.0740 - val_loss: 0.0313 - 88ms/epoch - 4ms/step
# Epoch 326/400
# 23/23 - 0s - loss: 0.0616 - val_loss: 0.0314 - 89ms/epoch - 4ms/step
# Epoch 327/400
# 23/23 - 0s - loss: 0.0624 - val_loss: 0.0308 - 97ms/epoch - 4ms/step
# Epoch 328/400
# 23/23 - 0s - loss: 0.0779 - val_loss: 0.0319 - 103ms/epoch - 4ms/step
# Epoch 329/400
# 23/23 - 0s - loss: 0.0691 - val_loss: 0.0320 - 97ms/epoch - 4ms/step
# Epoch 330/400
# 23/23 - 0s - loss: 0.0781 - val_loss: 0.0316 - 104ms/epoch - 5ms/step
# Epoch 331/400
# 23/23 - 0s - loss: 0.0674 - val_loss: 0.0305 - 123ms/epoch - 5ms/step
# Epoch 332/400
# 23/23 - 0s - loss: 0.0683 - val_loss: 0.0309 - 122ms/epoch - 5ms/step
# Epoch 333/400
# 23/23 - 0s - loss: 0.0754 - val_loss: 0.0308 - 112ms/epoch - 5ms/step
# Epoch 334/400
# 23/23 - 0s - loss: 0.0686 - val_loss: 0.0304 - 100ms/epoch - 4ms/step
# Epoch 335/400
# 23/23 - 0s - loss: 0.0681 - val_loss: 0.0301 - 117ms/epoch - 5ms/step
# Epoch 336/400
# 23/23 - 0s - loss: 0.0734 - val_loss: 0.0311 - 100ms/epoch - 4ms/step
# Epoch 337/400
# 23/23 - 0s - loss: 0.0702 - val_loss: 0.0303 - 117ms/epoch - 5ms/step
# Epoch 338/400
# 23/23 - 0s - loss: 0.0675 - val_loss: 0.0309 - 99ms/epoch - 4ms/step
# Epoch 339/400
# 23/23 - 0s - loss: 0.0676 - val_loss: 0.0310 - 101ms/epoch - 4ms/step
# Epoch 340/400
# 23/23 - 0s - loss: 0.0674 - val_loss: 0.0302 - 100ms/epoch - 4ms/step
# Epoch 341/400
# 23/23 - 0s - loss: 0.0704 - val_loss: 0.0300 - 100ms/epoch - 4ms/step
# Epoch 342/400
# 23/23 - 0s - loss: 0.0710 - val_loss: 0.0305 - 111ms/epoch - 5ms/step
# Epoch 343/400
# 23/23 - 0s - loss: 0.0694 - val_loss: 0.0305 - 109ms/epoch - 5ms/step
# Epoch 344/400
# 23/23 - 0s - loss: 0.0699 - val_loss: 0.0304 - 115ms/epoch - 5ms/step
# Epoch 345/400
# 23/23 - 0s - loss: 0.0648 - val_loss: 0.0315 - 166ms/epoch - 7ms/step
# Epoch 346/400
# 23/23 - 0s - loss: 0.0682 - val_loss: 0.0305 - 112ms/epoch - 5ms/step
# Epoch 347/400
# 23/23 - 0s - loss: 0.0731 - val_loss: 0.0301 - 109ms/epoch - 5ms/step
# Epoch 348/400
# 23/23 - 0s - loss: 0.0643 - val_loss: 0.0299 - 100ms/epoch - 4ms/step
# Epoch 349/400
# 23/23 - 0s - loss: 0.0697 - val_loss: 0.0305 - 117ms/epoch - 5ms/step
# Epoch 350/400
# 23/23 - 0s - loss: 0.0606 - val_loss: 0.0299 - 132ms/epoch - 6ms/step
# Epoch 351/400
# 23/23 - 0s - loss: 0.0684 - val_loss: 0.0309 - 105ms/epoch - 5ms/step
# Epoch 352/400
# 23/23 - 0s - loss: 0.0734 - val_loss: 0.0307 - 98ms/epoch - 4ms/step
# Epoch 353/400
# 23/23 - 0s - loss: 0.0741 - val_loss: 0.0314 - 112ms/epoch - 5ms/step
# Epoch 354/400
# 23/23 - 0s - loss: 0.0673 - val_loss: 0.0311 - 100ms/epoch - 4ms/step
# Epoch 355/400
# 23/23 - 0s - loss: 0.0671 - val_loss: 0.0305 - 111ms/epoch - 5ms/step
# Epoch 356/400
# 23/23 - 0s - loss: 0.0698 - val_loss: 0.0309 - 119ms/epoch - 5ms/step
# Epoch 357/400
# 23/23 - 0s - loss: 0.0750 - val_loss: 0.0304 - 125ms/epoch - 5ms/step
# Epoch 358/400
# 23/23 - 0s - loss: 0.0687 - val_loss: 0.0303 - 117ms/epoch - 5ms/step
# Epoch 359/400
# 23/23 - 0s - loss: 0.0634 - val_loss: 0.0303 - 107ms/epoch - 5ms/step
# Epoch 360/400
# 23/23 - 0s - loss: 0.0637 - val_loss: 0.0308 - 112ms/epoch - 5ms/step
# Epoch 361/400
# 23/23 - 0s - loss: 0.0702 - val_loss: 0.0302 - 101ms/epoch - 4ms/step
# Epoch 362/400
# 23/23 - 0s - loss: 0.0631 - val_loss: 0.0298 - 114ms/epoch - 5ms/step
# Epoch 363/400
# 23/23 - 0s - loss: 0.0620 - val_loss: 0.0299 - 106ms/epoch - 5ms/step
# Epoch 364/400
# 23/23 - 0s - loss: 0.0714 - val_loss: 0.0306 - 87ms/epoch - 4ms/step
# Epoch 365/400
# 23/23 - 0s - loss: 0.0652 - val_loss: 0.0303 - 101ms/epoch - 4ms/step
# Epoch 366/400
# 23/23 - 0s - loss: 0.0697 - val_loss: 0.0311 - 106ms/epoch - 5ms/step
# Epoch 367/400
# 23/23 - 0s - loss: 0.0742 - val_loss: 0.0300 - 95ms/epoch - 4ms/step
# Epoch 368/400
# 23/23 - 0s - loss: 0.0686 - val_loss: 0.0308 - 100ms/epoch - 4ms/step
# Epoch 369/400
# 23/23 - 0s - loss: 0.0595 - val_loss: 0.0299 - 106ms/epoch - 5ms/step
# Epoch 370/400
# 23/23 - 0s - loss: 0.0724 - val_loss: 0.0310 - 107ms/epoch - 5ms/step
# Epoch 371/400
# 23/23 - 0s - loss: 0.0691 - val_loss: 0.0302 - 100ms/epoch - 4ms/step
# Epoch 372/400
# 23/23 - 0s - loss: 0.0626 - val_loss: 0.0294 - 106ms/epoch - 5ms/step
# Epoch 373/400
# 23/23 - 0s - loss: 0.0649 - val_loss: 0.0302 - 98ms/epoch - 4ms/step
# Epoch 374/400
# 23/23 - 0s - loss: 0.0766 - val_loss: 0.0301 - 109ms/epoch - 5ms/step
# Epoch 375/400
# 23/23 - 0s - loss: 0.0648 - val_loss: 0.0297 - 88ms/epoch - 4ms/step
# Epoch 376/400
# 23/23 - 0s - loss: 0.0577 - val_loss: 0.0287 - 95ms/epoch - 4ms/step
# Epoch 377/400
# 23/23 - 0s - loss: 0.0706 - val_loss: 0.0297 - 98ms/epoch - 4ms/step
# Epoch 378/400
# 23/23 - 0s - loss: 0.0712 - val_loss: 0.0300 - 86ms/epoch - 4ms/step
# Epoch 379/400
# 23/23 - 0s - loss: 0.0673 - val_loss: 0.0293 - 97ms/epoch - 4ms/step
# Epoch 380/400
# 23/23 - 0s - loss: 0.0672 - val_loss: 0.0292 - 98ms/epoch - 4ms/step
# Epoch 381/400
# 23/23 - 0s - loss: 0.0738 - val_loss: 0.0297 - 102ms/epoch - 4ms/step
# Epoch 382/400
# 23/23 - 0s - loss: 0.0596 - val_loss: 0.0294 - 107ms/epoch - 5ms/step
# Epoch 383/400
# 23/23 - 0s - loss: 0.0706 - val_loss: 0.0302 - 131ms/epoch - 6ms/step
# Epoch 384/400
# 23/23 - 0s - loss: 0.0676 - val_loss: 0.0302 - 120ms/epoch - 5ms/step
# Epoch 385/400
# 23/23 - 0s - loss: 0.0631 - val_loss: 0.0293 - 145ms/epoch - 6ms/step
# Epoch 386/400
# 23/23 - 0s - loss: 0.0667 - val_loss: 0.0289 - 108ms/epoch - 5ms/step
# Epoch 387/400
# 23/23 - 0s - loss: 0.0646 - val_loss: 0.0297 - 113ms/epoch - 5ms/step
# Epoch 388/400
# 23/23 - 0s - loss: 0.0735 - val_loss: 0.0298 - 107ms/epoch - 5ms/step
# Epoch 389/400
# 23/23 - 0s - loss: 0.0641 - val_loss: 0.0289 - 105ms/epoch - 5ms/step
# Epoch 390/400
# 23/23 - 0s - loss: 0.0576 - val_loss: 0.0285 - 105ms/epoch - 5ms/step
# Epoch 391/400
# 23/23 - 0s - loss: 0.0711 - val_loss: 0.0284 - 99ms/epoch - 4ms/step
# Epoch 392/400
# 23/23 - 0s - loss: 0.0641 - val_loss: 0.0288 - 113ms/epoch - 5ms/step
# Epoch 393/400
# 23/23 - 0s - loss: 0.0640 - val_loss: 0.0288 - 97ms/epoch - 4ms/step
# Epoch 394/400
# 23/23 - 0s - loss: 0.0705 - val_loss: 0.0294 - 107ms/epoch - 5ms/step
# Epoch 395/400
# 23/23 - 0s - loss: 0.0722 - val_loss: 0.0293 - 97ms/epoch - 4ms/step
# Epoch 396/400
# 23/23 - 0s - loss: 0.0675 - val_loss: 0.0292 - 106ms/epoch - 5ms/step
# Epoch 397/400
# 23/23 - 0s - loss: 0.0699 - val_loss: 0.0287 - 100ms/epoch - 4ms/step
# Epoch 398/400
# 23/23 - 0s - loss: 0.0675 - val_loss: 0.0289 - 101ms/epoch - 4ms/step
# Epoch 399/400
# 23/23 - 0s - loss: 0.0620 - val_loss: 0.0284 - 99ms/epoch - 4ms/step
# Epoch 400/400
# 23/23 - 0s - loss: 0.0677 - val_loss: 0.0287 - 94ms/epoch - 4ms/step

# %% [markdown]
# ##### 4. Plot results

# %%
# plot loss
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
